# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(r'..\smart_allocation_engine_raw_data.csv')

# %%
prof = ProfileReport(df)
prof.to_file(output_file = 'smart_allocation_engine_analysis.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
